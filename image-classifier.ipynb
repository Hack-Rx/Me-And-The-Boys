# %%
from google.colab import drive
drive.mount('/content/bajajhacx')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/bajajhacx

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
cd bajajhacx/My\ Drive
# Out:
# /content/bajajhacx/My Drive

# %%
path = Path('hacxdataset')

# %%
classes = ['ashish','bhuvanbam','carryminati','drinking','dualipa','helmet','messi','nudity','pwediepie','ronaldo','seatbelt','smoking']

for c in classes:
  print(c)
  verify_images(path/c, delete = True, max_size = 500)
# Out:
# ashish
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:987: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:987: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# bhuvanbam
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:987: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# carryminati
# drinking
# dualipa
# helmet
# messi
# nudity
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:987: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# pwediepie
# ronaldo
# seatbelt
# smoking

# %%
data = ImageDataBunch.from_folder(path, train='.', valid_pct = 0.2, seed=66,
                                  ds_tfms = get_transforms(), size = 224).normalize(imagenet_stats)
data.show_batch(rows = 5, figsize = (10,10))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
print(data.classes)
print(len(data.train_ds))
print(len(data.valid_ds))
# Out:
# ['ashish', 'bhuvanbam', 'carryminati', 'drinking', 'dualipa', 'helmet', 'messi', 'nudity', 'pwediepie', 'ronaldo', 'seatbelt', 'smoking']
# 1488
# 371

# %%
learn = cnn_learner(data, models.resnet34, metrics = error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(12)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.186933</td>
#       <td>1.561095</td>
#       <td>0.485175</td>
#       <td>08:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.201569</td>
#       <td>1.038628</td>
#       <td>0.280323</td>
#       <td>08:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.646186</td>
#       <td>1.068762</td>
#       <td>0.272237</td>
#       <td>08:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.311094</td>
#       <td>0.882687</td>
#       <td>0.250674</td>
#       <td>08:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.086964</td>
#       <td>0.941871</td>
#       <td>0.253369</td>
#       <td>08:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-1')

# %%
learn.export('stage-1.pkl')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 32:35<21:43]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.fit_one_cycle(3,max_lr=slice(3e-5,3e-4))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 23:30<11:45]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...
